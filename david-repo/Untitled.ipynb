# %%
import pandas as pd

# %%
sso = pd.read_csv('SSO_with_zip_codes.csv', index_col=0)
df_311 = pd.read_csv('cleaned_311.csv', index_col=0)

# %%
sso.sample(3)
# Out:
#                 report_date  spill_address_num spill_st_name  total_gal  \
# sso_id
# 20      2010-11-03 00:00:00                714    GROVE BEND         25
# 5914    2016-05-24 00:00:00                680    BASSE RD E       1250
# 6375    2018-06-08 00:00:00                300    WALTON AVE         59
#
#         gals_ret          spill_start           spill_stop       hrs   cause  \
# sso_id
# 20           0.0  2010-11-03 07:52:00  2010-11-03 08:17:00  0.416667    Rags
# 5914         0.0  2016-05-24 08:32:00  2016-05-24 09:20:00  0.800000  Grease
# 6375         0.0  2018-06-08 09:49:00  2018-06-08 10:48:00  0.983333  Grease
#
#                                                  comments  ...  root_cause  \
# sso_id                                                     ...
# 20                                           APPLIED  HTH  ...      debris
# 5914          Spill ContainedArea Cleaned and Disinfected  ...      grease
# ...

# %%
df_311.sample(3)
# Out:
#                         category     case_id late                      dept  \
# 234496  Streets & Infrastructure  1015895698   NO  Trans & Cap Improvements
# 291853  Streets & Infrastructure  1015963519   NO  Trans & Cap Improvements
# 197131  Streets & Infrastructure  1015848754   NO  Trans & Cap Improvements
#
#         reason_name                           event_name case_status  \
# 234496  Storm Water               Drainage Investigation      Closed
# 291853  Storm Water  Drainage Inlet - Cleaning/Foul Odor      Closed
# 197131  Storm Water      Drainage Channel/Debris Removal      Closed
#
#                 sourceid                          event_address  \
# 234496  Constituent Call    2014  BEECHAVEN, San Antonio, 78207
# 291853  Constituent Call  254  MARBAUCH AVE, San Antonio, 78237
# 197131  Constituent Call       2434  SW 410, San Antonio, 78227
#
#         council_district  ... zip_code               reported_date  \
# ...

# %%
joined_df_merge = pd.merge(sso, df_311, on='zip_code')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e3101f1459f3> in <module>
# ----> 1 joined_df_merge = pd.merge(sso, df_311, on='zip_code')
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# ...

# %%
sso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3183 entries, 0 to 3182
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sso_id               3183 non-null   int64
#  1   report_date          3183 non-null   object
#  2   spill_address_num    3183 non-null   int64
#  3   spill_st_name        3183 non-null   object
#  4   total_gal            3183 non-null   int64
#  5   gals_ret             2708 non-null   float64
#  6   spill_start          3183 non-null   object
#  7   spill_stop           3183 non-null   object
#  8   hrs                  3180 non-null   float64
#  9   cause                3183 non-null   object
#  10  comments             2650 non-null   object
#  11  actions              3175 non-null   object
#  12  watershed            3183 non-null   object
#  13  unit_id              3179 non-null   object
#  14  unit_id2             2939 non-null   object
# ...

# %%
df_311.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1677 entries, 8362 to 304395
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   category                 1677 non-null   object
#  1   case_id                  1677 non-null   int64
#  2   late                     1677 non-null   object
#  3   dept                     1677 non-null   object
#  4   reason_name              1677 non-null   object
#  5   event_name               1677 non-null   object
#  6   case_status              1677 non-null   object
#  7   sourceid                 1677 non-null   object
#  8   event_address            1677 non-null   object
#  9   council_district         1677 non-null   int64
#  10  report_start_date        1677 non-null   object
#  11  report_ending_date       1677 non-null   object
#  12  zip_code                 1677 non-null   int64
#  13  reported_date            1677 non-null   object
# ...
