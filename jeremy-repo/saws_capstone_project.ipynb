# %% [markdown]
# # Saws Capstone Project
#
# ## Introduction
#
# The San Antonio Water System (SAWS) has collected a dataset of over 3100 Sanitary Sewer Overflow (SSO) events going back to 2009. The data on these events contains a wealth of information about the event, including the root cause that was determined. We know that some of the events are weather related so we will be using data collected by National Oceanic and Atomospheric Administration (NOAA) in combination with the SSO events to provide better insights into what causes these events. It is our hope that these insights can be used by the city of San Antonio and SAWS to plan preventative measures that will benefit the city in the future.
#
# ## Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns', None)

from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import classification_report
from sklearn import tree
from scipy import stats

import graphviz
from graphviz import Graph

import warnings
warnings.filterwarnings("ignore")

import acquire
import explore
import prepare
import preprocessing
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Acquire
#
# ### Acquisition of San Antonio Sanitary Sewer Overflow (SSO) Data
#
# The SSO data is collected from the CivTech San Antonio's Datathon website. [CivTechSA](https://www.civtech-sa.com/datathon/)
#
# Data use in this notebook can be found here: [Datathon SSO data](https://storage.googleapis.com/sa_saws_data/SAWS_SSOs_2009-2018Mar_UploadData.xlsx)
# * The data includes information on age of sewer, initial reported causes, and investigation reported causes  .

# %%
sso = acquire.acquire_sso()
sso
# Out:
#       SSO_ID   INSPKEY  SERVNO           REPORTDATE  SPILL_ADDRESS  \
# 0       6582  567722.0     NaN  2019-03-10 00:00:00           3200
# 1       6583  567723.0     NaN  2019-03-10 00:00:00           6804
# 2       6581  567714.0     NaN  2019-03-09 00:00:00            215
# 3       6584  567713.0     NaN  2019-03-09 00:00:00           3602
# 4       6580  567432.0     NaN  2019-03-06 00:00:00            100
# ...      ...       ...     ...                  ...            ...
# 3178     371       NaN     NaN  2009-01-06 00:00:00           2383
# 3179     372       NaN     NaN  2009-01-05 00:00:00           7407
# 3180     373       NaN     NaN  2009-01-05 00:00:00           7019
# 3181     375       NaN     NaN  2009-01-05 00:00:00          12500
# 3182     374       NaN     NaN  2009-01-03 00:00:00            215
#
#          SPILL_ST_NAME  TOTAL_GAL  GALSRET     GAL           SPILL_START  \
# 0     THOUSAND OAKS DR       2100   2100.0  2100.0  3/10/2019 1:16:00 PM
# 1          S FLORES ST         80      0.0    80.0  3/10/2019 2:25:00 PM
# 2      AUDREY ALENE DR         79      0.0    10.0   3/9/2019 6:00:00 PM
# 3       SE MILITARY DR         83      0.0    83.0   3/9/2019 3:37:00 PM
# 4             PANSY LN         75      0.0    75.0   3/6/2019 9:40:00 AM
# ...                ...        ...      ...     ...                   ...
# 3178       LOOP 410 NE       2000      NaN  2000.0  1/6/2009 12:00:00 PM
# 3179        ELDERBERRY        800      NaN   800.0   1/5/2009 2:00:00 PM
# 3180          BAYWATER        400      NaN   400.0  1/5/2009 11:00:00 AM
# 3181        JOHN BARRY         25      NaN    25.0   1/5/2009 8:30:00 AM
# 3182       BROADVIEW W        500      NaN   500.0   1/3/2009 9:00:00 AM
#
#                 SPILL_STOP       HRS        CAUSE  \
# 0     3/10/2019 2:40:00 PM  1.400000       Grease
# 1     3/10/2019 3:45:00 PM  1.333333       Grease
# 2      3/9/2019 7:30:00 PM  1.500000   Structural
# 3      3/9/2019 5:00:00 PM  1.383333       Grease
# 4      3/6/2019 9:55:00 AM  0.250000   Structural
# ...                    ...       ...          ...
# 3178   1/6/2009 1:00:00 PM  1.000000  Debris/Rock
# 3179   1/5/2009 4:00:00 PM  2.000000         Rags
# 3180  1/5/2009 11:45:00 AM  0.750000         Rags
# 3181   1/5/2009 9:00:00 AM  0.500000  Debris/Rock
# 3182  1/3/2009 11:00:00 AM  2.000000         Rags
#
#                                                COMMENTS       ACTIONS  \
# 0     Spill ContainedReturned to SystemArea Cleaned ...  CLEANED MAIN
# 1           Spill ContainedArea Cleaned and Disinfected  CLEANED MAIN
# 2     Spill ContainedArea Cleaned and DisinfectedFlu...  CLEANED MAIN
# 3     Spill ContainedArea Cleaned and DisinfectedFlu...           NaN
# 4     Spill ContainedArea Cleaned and DisinfectedFlu...  CLEANED MAIN
# ...                                                 ...           ...
# 3178                                       CLEANED MAIN   APPLIED HTH
# 3179                                       CLEANED MAIN   APPLIED HTH
# 3180                                       CLEANED MAIN   APPLIED HTH
# 3181                                       CLEANED MAIN   APPLIED HTH
# 3182                                       CLEANED MAIN   APPLIED HTH
#
#          WATERSHED UNITID UNITID2      DISCHARGE_TO DISCHARGE_ROUTE  \
# 0     SALADO CREEK  66918   66917            STREET            None
# 1         DOS RIOS  24250   24193        STORMDRAIN            None
# 2         DOS RIOS   2822    3351             ALLEY            None
# 3     SALADO CREEK  92804   92805          EASEMENT            None
# 4     SALADO CREEK  61141   49543            STREET            None
# ...            ...    ...     ...               ...             ...
# 3178  SALADO CREEK  46343   59920  DRAINAGE CULVERT             NaN
# 3179    LEON CREEK  89038   74015            STREET             NaN
# 3180    LEON CREEK  51874   51883  DRAINAGE CULVERT             NaN
# 3181  SALADO CREEK  50793   51175  DRAINAGE CULVERT             NaN
# 3182    LEON CREEK  64143   75613  DRAINAGE CULVERT             NaN
#
#       COUNCIL_DISTRICT FERGUSON  Month  Year  Week  EARZ_ZONE    Expr1029  \
# 0                  NaN    172A2      3  2019    11        0.0         NaN
# 1                  3.0    251A3      3  2019    11        0.0         NaN
# 2                  1.0    190E4      3  2019    10        0.0         NaN
# 3                  3.0    252C3      3  2019    10        0.0         NaN
# 4                  2.0    192A7      3  2019    10        0.0         NaN
# ...                ...      ...    ...   ...   ...        ...         ...
# 3178              10.0    552B8      1  2009     2        NaN  STRUCTURAL
# 3179               7.0    547F7      1  2009     2        NaN  STRUCTURAL
# 3180               8.0    580F2      1  2009     2        NaN      DEBRIS
# 3181              10.0    553B3      1  2009     2        NaN  STRUCTURAL
# 3182               7.0    580F7      1  2009     1        NaN      DEBRIS
#
#       PIPEDIAM     PIPELEN PIPETYPE  INSTYEAR  DWNDPTH  UPSDPTH  Inches_No  \
# 0          8.0   16.550000      PVC    1997.0      NaN      NaN        NaN
# 1          8.0  157.000000      PVC    1988.0      NaN      NaN        NaN
# 2          8.0  350.000000       CP    1955.0      NaN      NaN        NaN
# 3          8.0  213.910000      PVC    1983.0      NaN      NaN        NaN
# 4         12.0  291.900000       CP    1952.0      NaN      NaN        NaN
# ...        ...         ...      ...       ...      ...      ...        ...
# 3178       8.0  400.000000      VCP    1966.0      NaN      NaN        NaN
# 3179       8.0  151.877494      VCP    1976.0      NaN      NaN        NaN
# 3180       8.0  380.870000      VCP    1958.0      NaN      NaN        NaN
# 3181       8.0  395.260000      VCP    1972.0      NaN      NaN        NaN
# 3182       8.0  159.325718      VCP    1957.0      NaN      NaN        NaN
#
#       RainFall_Less3          SPILL ADDRESS        SewerAssetExp  \
# 0                NaN  3200 THOUSAND OAKS DR                  NaN
# 1                NaN          6804 S FLORES                  NaN
# 2                NaN    215 Audrey Alene Dr                  NaN
# 3                NaN    3602 SE MILITARY DR                  NaN
# 4                NaN           100 PANSY LN                  NaN
# ...              ...                    ...                  ...
# 3178             NaN      NE LOOP 410 02383                  NaN
# 3179             NaN       ELDERBERRY 07407  2009-10-09 09:21:05
# 3180             NaN      BAYWATER DR 07019                  NaN
# 3181             NaN       JOHN BARRY 125/1                  NaN
# 3182             NaN                    NaN  2009-10-09 09:21:05
#
#       NUM_SPILLS_COMPKEY  NUM_SPILLS_24MOS      PREVSPILL_24MOS UNITTYPE  \
# 0                      1               1.0                  NaN  GRAVITY
# 1                      1               1.0                  NaN  GRAVITY
# 2                      1               1.0                  NaN  GRAVITY
# 3                      1               1.0                  NaN  GRAVITY
# 4                      2               2.0  2018-12-15 00:00:00  GRAVITY
# ...                  ...               ...                  ...      ...
# 3178                   1               NaN                  NaN  GRAVITY
# 3179                   2               NaN                  NaN  GRAVITY
# 3180                   1               NaN                  NaN  GRAVITY
# 3181                   1               NaN                  NaN  GRAVITY
# 3182                   3               NaN                  NaN  GRAVITY
#
#        ASSETTYPE LASTCLND  ResponseTime         ResponseDTTM  Public Notice  \
# 0     Sewer Main      NaN      0.450000  2019-03-10 13:43:00          False
# 1     Sewer Main      NaN      1.083333  2019-03-10 15:30:00          False
# 2     Sewer Main      NaN      1.000000  2019-03-09 19:00:00          False
# 3     Sewer Main      NaN      0.550000  2019-03-09 16:10:00          False
# 4     Sewer Main      NaN      0.000000  2019-03-06 09:40:00          False
# ...          ...      ...           ...                  ...            ...
# 3178  Sewer Main      NaN           NaN                  NaN          False
# 3179  Sewer Main      NaN           NaN                  NaN          False
# 3180  Sewer Main      NaN           NaN                  NaN          False
# 3181  Sewer Main      NaN           NaN                  NaN          False
# 3182  Sewer Main      NaN           NaN                  NaN          False
#
#       TIMEINT  Root_Cause STEPS_TO_PREVENT     SPILL_START_2  \
# 0        24.0         NaN              NaN               NaN
# 1       120.0         NaN              NaN               NaN
# 2        24.0         NaN              NaN  03/10/2019 09:36
# 3       120.0         NaN              NaN               NaN
# 4         3.0         NaN              NaN               NaN
# ...       ...         ...              ...               ...
# 3178      NaN  STRUCTURAL              NaN               NaN
# 3179      NaN  STRUCTURAL              NaN               NaN
# 3180      NaN      DEBRIS              NaN               NaN
# 3181      NaN  STRUCTURAL              NaN               NaN
# 3182      NaN      DEBRIS              NaN               NaN
#
#           SPILL_STOP_2  HRS_2  GAL_2 SPILL_START_3 SPILL_STOP_3  HRS_3  GAL_3
# 0                  NaN   0.00    0.0           NaN          NaN    0.0    0.0
# 1                  NaN   0.00    0.0           NaN          NaN    0.0    0.0
# 2     03/10/2019 10:45   1.15   69.0           NaN          NaN    0.0    0.0
# 3                  NaN   0.00    0.0           NaN          NaN    0.0    0.0
# 4                  NaN   0.00    0.0           NaN          NaN    0.0    0.0
# ...                ...    ...    ...           ...          ...    ...    ...
# 3178               NaN    NaN    NaN           NaN          NaN    NaN    NaN
# 3179               NaN    NaN    NaN           NaN          NaN    NaN    NaN
# 3180               NaN    NaN    NaN           NaN          NaN    NaN    NaN
# 3181               NaN    NaN    NaN           NaN          NaN    NaN    NaN
# 3182               NaN    NaN    NaN           NaN          NaN    NaN    NaN
#
# [3183 rows x 57 columns]

# %% [markdown]
# ### Acquisition of Weather Data

# %% [markdown]
# The weather data is collected from the National Centers for Environmental Information API. Documentation for the API can be found here: [NCEI API](https://www.ncei.noaa.gov/support/access-data-service-api-user-documentation)
# The API request can be found in the acquire file but the details are as follows:
# * The data is from the San Antonio International Airport
# * The data is the daily summary from December 3, 2008 to April 3, 2019
#     * While this is outside the range of the SSO events data, we have done this so that we can take rolling averages up to a month before the first event.
# * The data includes information on precipitation, wind, temperature, and a vast number of meteorological events.
# * The units for these recording are in standard format.

# %%
weather = acquire.acquire_weather()
weather
# Out:
#           STATION        DATE   AWND    FMTM    PGTM  PRCP  SNOW  SNWD  TAVG  \
# 0     USW00012921  2008-12-03   9.40  2302.0  2315.0   0.0   0.0   0.0   NaN
# 1     USW00012921  2008-12-04  11.41   828.0   506.0   0.0   0.0   0.0   NaN
# 2     USW00012921  2008-12-05   6.71   952.0   839.0   0.0   0.0   0.0   NaN
# 3     USW00012921  2008-12-06   3.80  1157.0  1132.0   0.0   0.0   0.0   NaN
# 4     USW00012921  2008-12-07   6.93  1557.0  1512.0   0.0   0.0   0.0   NaN
# ...           ...         ...    ...     ...     ...   ...   ...   ...   ...
# 3769  USW00012921  2019-03-30  13.87     NaN     NaN   0.0   0.0   0.0  67.0
# 3770  USW00012921  2019-03-31  10.96     NaN     NaN   0.0   0.0   0.0  52.0
# 3771  USW00012921  2019-04-01   5.59     NaN     NaN   0.0   0.0   0.0  51.0
# 3772  USW00012921  2019-04-02   8.05     NaN     NaN   0.0   0.0   0.0  53.0
# 3773  USW00012921  2019-04-03  11.41     NaN     NaN   0.0   0.0   0.0  62.0
#
#       TMAX  TMIN  WDF2   WDF5  WSF2  WSF5  WT01  WT02  WT03  WT05  WT06  WT07  \
# 0       77    48   360  350.0  19.9  38.0   1.0   NaN   NaN   NaN   NaN   NaN
# 1       61    39    20  350.0  21.0  29.1   NaN   NaN   NaN   NaN   NaN   NaN
# 2       55    36    20   30.0  15.0  21.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3       69    30   240  270.0  10.1  14.1   NaN   NaN   NaN   NaN   NaN   NaN
# 4       71    36   160  190.0  17.0  21.0   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 3769    70    51    10   20.0  32.0  40.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3770    59    44    20   30.0  25.1  35.1   NaN   NaN   NaN   NaN   NaN   NaN
# 3771    62    42   130  130.0  12.1  13.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3772    71    37   150  160.0  18.1  23.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3773    68    57   150  150.0  21.9  25.1   1.0   NaN   NaN   NaN   NaN   NaN
#
#       WT08  WT09  WT10  WT11  WT13  WT16  WT17  WT18  WT19
# 0      1.0   NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 3769   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3770   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3771   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3772   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3773   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [3774 rows x 30 columns]

# %% [markdown]
# ## Preparation
#
# ### Preparation of SSO Data

# %% [markdown]
# - What are we changing?
#     - We are removing columns that are listed as 'ignore' in the data dictionary provided along with the SSO data, as well as columns that are entirely null
#     - We change the column names to make them more understandable, we change the data types of some columns to work with them better, we impute some values to 0 or None, we replace many columns 'NaN's with 'unknown'
#     - We add 'days since cleaned', 'age', and 'number of hours spilled' columns
#     - We use geopy to take the street addresses and find the aligning ZIP codes. We turned that into a csv since it takes a very long time to do, so if you want to do this yourself, take that into account
#     - We add columns that turn age and gallons spilled into categorical bins

# %%
sso = prepare.prepare_sso_with_zipcodes()

# %% [markdown]
# ### Preparation of Weather Data
#
# * What are we changing?
#     * We are removing columns that are don't provide a lot of information.
#         * "STATION","AWND", "FMTM", "PGTM", "WDF2", "WDF5", "WSF2", "WSF5", "WT06", "WT07", "WT08", "WT10", "WT11", "WT13", "WT17", "WT18", "WT19"
#     * We changed the column names to make them more understandable.
#     * We imputed some missing values
#         * avg_temp was missing some values so we imputed with `(max_temp + min_temp ) / 2`
#         * All of the weather event columns are missing the 0 for if the event didn't happen that day so we replace NaNs with 0.
#     * We added rolling averages for precipitation, avg_temp, max_temp, and min_temp
#         * These were added at 7, 14, and 30 day periods

# %%
prepare.prep_weather_data()
# Out:
#             precipitation  snowfall  snow_depth  avg_temp  max_temp  min_temp  \
# date
# 2008-12-03            0.0       0.0         0.0      62.5        77        48
# 2008-12-04            0.0       0.0         0.0      50.0        61        39
# 2008-12-05            0.0       0.0         0.0      45.5        55        36
# 2008-12-06            0.0       0.0         0.0      49.5        69        30
# 2008-12-07            0.0       0.0         0.0      53.5        71        36
# ...                   ...       ...         ...       ...       ...       ...
# 2019-03-30            0.0       0.0         0.0      67.0        70        51
# 2019-03-31            0.0       0.0         0.0      52.0        59        44
# 2019-04-01            0.0       0.0         0.0      51.0        62        42
# 2019-04-02            0.0       0.0         0.0      53.0        71        37
# 2019-04-03            0.0       0.0         0.0      62.0        68        57
#
#             foggy  heavy_fog  thunder  hail  blowing_snow  rain  \
# date
# 2008-12-03      1          0        0     0             0     0
# 2008-12-04      0          0        0     0             0     0
# 2008-12-05      0          0        0     0             0     0
# 2008-12-06      0          0        0     0             0     0
# 2008-12-07      0          0        0     0             0     0
# ...           ...        ...      ...   ...           ...   ...
# 2019-03-30      0          0        0     0             0     0
# 2019-03-31      0          0        0     0             0     0
# 2019-04-01      0          0        0     0             0     0
# 2019-04-02      0          0        0     0             0     0
# 2019-04-03      1          0        0     0             0     0
#
#             precipitation_rolling_7  precipitation_rolling_14  \
# date
# 2008-12-03                      NaN                       NaN
# 2008-12-04                      NaN                       NaN
# 2008-12-05                      NaN                       NaN
# 2008-12-06                      NaN                       NaN
# 2008-12-07                      NaN                       NaN
# ...                             ...                       ...
# 2019-03-30             1.428571e-03                  0.019286
# 2019-03-31             1.428571e-03                  0.019286
# 2019-04-01             1.103532e-15                  0.019286
# 2019-04-02             1.103532e-15                  0.019286
# 2019-04-03             1.103532e-15                  0.000714
#
#             precipitation_rolling_30  avg_temp_rolling_7  avg_temp_rolling_14  \
# date
# 2008-12-03                       NaN                 NaN                  NaN
# 2008-12-04                       NaN                 NaN                  NaN
# 2008-12-05                       NaN                 NaN                  NaN
# 2008-12-06                       NaN                 NaN                  NaN
# 2008-12-07                       NaN                 NaN                  NaN
# ...                              ...                 ...                  ...
# 2019-03-30                  0.015333           68.000000            64.142857
# 2019-03-31                  0.015000           65.571429            64.071429
# 2019-04-01                  0.015000           62.428571            63.785714
# 2019-04-02                  0.015000           60.285714            63.500000
# 2019-04-03                  0.015000           60.000000            63.500000
#
#             avg_temp_rolling_30  max_temp_rolling_7  max_temp_rolling_14  \
# date
# 2008-12-03                  NaN                 NaN                  NaN
# 2008-12-04                  NaN                 NaN                  NaN
# 2008-12-05                  NaN                 NaN                  NaN
# 2008-12-06                  NaN                 NaN                  NaN
# 2008-12-07                  NaN                 NaN                  NaN
# ...                         ...                 ...                  ...
# 2019-03-30            60.733333           78.571429            75.142857
# 2019-03-31            60.833333           75.428571            74.785714
# 2019-04-01            60.666667           72.000000            74.357143
# 2019-04-02            60.733333           71.000000            74.571429
# 2019-04-03            61.633333           69.857143            74.071429
#
#             max_temp_rolling_30  min_temp_rolling_7  min_temp_rolling_14  \
# date
# 2008-12-03                  NaN                 NaN                  NaN
# 2008-12-04                  NaN                 NaN                  NaN
# 2008-12-05                  NaN                 NaN                  NaN
# 2008-12-06                  NaN                 NaN                  NaN
# 2008-12-07                  NaN                 NaN                  NaN
# ...                         ...                 ...                  ...
# 2019-03-30            70.600000           58.428571            54.142857
# 2019-03-31            70.633333           55.428571            54.285714
# 2019-04-01            70.666667           52.428571            54.142857
# 2019-04-02            71.266667           49.714286            53.642857
# 2019-04-03            72.200000           50.428571            53.785714
#
#             min_temp_rolling_30
# date
# 2008-12-03                  NaN
# 2008-12-04                  NaN
# 2008-12-05                  NaN
# 2008-12-06                  NaN
# 2008-12-07                  NaN
# ...                         ...
# 2019-03-30            51.266667
# 2019-03-31            51.200000
# 2019-04-01            50.833333
# 2019-04-02            50.866667
# 2019-04-03            51.766667
#
# [3774 rows x 24 columns]

# %% [markdown]
# ### Joining SSO and Weather Data
#
# After we have prepared both datasets we are now able to join the SSO events on to the weather data by date.

# %%
df = prepare.get_data()
df
# Out:
#       sso_id report_date  spill_address_num     spill_st_name  total_gal  \
# 0       6582  2019-03-10               3200  THOUSAND OAKS DR       2100
# 1       6583  2019-03-10               6804       S FLORES ST         80
# 2       6581  2019-03-09                215   AUDREY ALENE DR         79
# 3       6584  2019-03-09               3602    SE MILITARY DR         83
# 4       6580  2019-03-06                100          PANSY LN         75
# ...      ...         ...                ...               ...        ...
# 3178     371  2009-01-06               2383       LOOP 410 NE       2000
# 3179     372  2009-01-05               7407        ELDERBERRY        800
# 3180     373  2009-01-05               7019          BAYWATER        400
# 3181     375  2009-01-05              12500        JOHN BARRY         25
# 3182     374  2009-01-03                215       BROADVIEW W        500
#
#       gals_ret         spill_start          spill_stop       hrs        cause  \
# 0       2100.0 2019-03-10 13:16:00 2019-03-10 14:40:00  1.400000       Grease
# 1          0.0 2019-03-10 14:25:00 2019-03-10 15:45:00  1.333333       Grease
# 2          0.0 2019-03-09 18:00:00 2019-03-09 19:30:00  1.500000   Structural
# 3          0.0 2019-03-09 15:37:00 2019-03-09 17:00:00  1.383333       Grease
# 4          0.0 2019-03-06 09:40:00 2019-03-06 09:55:00  0.250000   Structural
# ...        ...                 ...                 ...       ...          ...
# 3178       NaN 2009-01-06 12:00:00 2009-01-06 13:00:00  1.000000  Debris/Rock
# 3179       NaN 2009-01-05 14:00:00 2009-01-05 16:00:00  2.000000         Rags
# 3180       NaN 2009-01-05 11:00:00 2009-01-05 11:45:00  0.750000         Rags
# 3181       NaN 2009-01-05 08:30:00 2009-01-05 09:00:00  0.500000  Debris/Rock
# 3182       NaN 2009-01-03 09:00:00 2009-01-03 11:00:00  2.000000         Rags
#
#                                                comments       actions  \
# 0     Spill ContainedReturned to SystemArea Cleaned ...  CLEANED MAIN
# 1           Spill ContainedArea Cleaned and Disinfected  CLEANED MAIN
# 2     Spill ContainedArea Cleaned and DisinfectedFlu...  CLEANED MAIN
# 3     Spill ContainedArea Cleaned and DisinfectedFlu...           NaN
# 4     Spill ContainedArea Cleaned and DisinfectedFlu...  CLEANED MAIN
# ...                                                 ...           ...
# 3178                                       CLEANED MAIN   APPLIED HTH
# 3179                                       CLEANED MAIN   APPLIED HTH
# 3180                                       CLEANED MAIN   APPLIED HTH
# 3181                                       CLEANED MAIN   APPLIED HTH
# 3182                                       CLEANED MAIN   APPLIED HTH
#
#          watershed unit_id unit_id2      discharge_to discharge_route  \
# 0     SALADO CREEK   66918    66917            STREET            None
# 1         DOS RIOS   24250    24193        STORMDRAIN            None
# 2         DOS RIOS    2822     3351             ALLEY            None
# 3     SALADO CREEK   92804    92805          EASEMENT            None
# 4     SALADO CREEK   61141    49543            STREET            None
# ...            ...     ...      ...               ...             ...
# 3178  SALADO CREEK   46343    59920  DRAINAGE CULVERT            none
# 3179    LEON CREEK   89038    74015            STREET            none
# 3180    LEON CREEK   51874    51883  DRAINAGE CULVERT            none
# 3181  SALADO CREEK   50793    51175  DRAINAGE CULVERT            none
# 3182    LEON CREEK   64143    75613  DRAINAGE CULVERT            none
#
#       council_district  month  year  week earz_zone  pipe_diam    pipe_len  \
# 0                  NaN      3  2019    11         0        8.0   16.550000
# 1                  3.0      3  2019    11         0        8.0  157.000000
# 2                  1.0      3  2019    10         0        8.0  350.000000
# 3                  3.0      3  2019    10         0        8.0  213.910000
# 4                  2.0      3  2019    10         0       12.0  291.900000
# ...                ...    ...   ...   ...       ...        ...         ...
# 3178              10.0      1  2009     2         0        8.0  400.000000
# 3179               7.0      1  2009     2         0        8.0  151.877494
# 3180               8.0      1  2009     2         0        8.0  380.870000
# 3181              10.0      1  2009     2         0        8.0  395.260000
# 3182               7.0      1  2009     1         0        8.0  159.325718
#
#      pipe_type inst_year  inches_no  rainfall_last3     spill_address_full  \
# 0          PVC    1997.0        NaN             NaN  3200 THOUSAND OAKS DR
# 1          PVC    1988.0        NaN             NaN          6804 S FLORES
# 2           CP    1955.0        NaN             NaN    215 Audrey Alene Dr
# 3          PVC    1983.0        NaN             NaN    3602 SE MILITARY DR
# 4           CP    1952.0        NaN             NaN           100 PANSY LN
# ...        ...       ...        ...             ...                    ...
# 3178       VCP    1966.0        NaN             NaN      NE LOOP 410 02383
# 3179       VCP    1976.0        NaN             NaN       ELDERBERRY 07407
# 3180       VCP    1958.0        NaN             NaN      BAYWATER DR 07019
# 3181       VCP    1972.0        NaN             NaN       JOHN BARRY 125/1
# 3182       VCP    1957.0        NaN             NaN                    NaN
#
#       num_spills_recorded  num_spills_24mos      prevspill_24mos unit_type  \
# 0                       1               1.0                    0   GRAVITY
# 1                       1               1.0                    0   GRAVITY
# 2                       1               1.0                    0   GRAVITY
# 3                       1               1.0                    0   GRAVITY
# 4                       2               2.0  2018-12-15 00:00:00   GRAVITY
# ...                   ...               ...                  ...       ...
# 3178                    1               0.0                    0   GRAVITY
# 3179                    2               0.0                    0   GRAVITY
# 3180                    1               0.0                    0   GRAVITY
# 3181                    1               0.0                    0   GRAVITY
# 3182                    3               0.0                    0   GRAVITY
#
#       asset_type last_cleaned  response_time       response_dttm  \
# 0     Sewer Main          NaN           27.0 2019-03-10 13:43:00
# 1     Sewer Main          NaN           65.0 2019-03-10 15:30:00
# 2     Sewer Main          NaN           60.0 2019-03-09 19:00:00
# 3     Sewer Main          NaN           33.0 2019-03-09 16:10:00
# 4     Sewer Main          NaN            0.0 2019-03-06 09:40:00
# ...          ...          ...            ...                 ...
# 3178  Sewer Main          NaN            NaN                 NaT
# 3179  Sewer Main          NaN            NaN                 NaT
# 3180  Sewer Main          NaN            NaN                 NaT
# 3181  Sewer Main          NaN            NaN                 NaT
# 3182  Sewer Main          NaN            NaN                 NaT
#
#       public_notice  root_cause  hrs_2  gal_2  hrs_3  gal_3  \
# 0             False       other   0.00    0.0    0.0    0.0
# 1             False       other   0.00    0.0    0.0    0.0
# 2             False       other   1.15   69.0    0.0    0.0
# 3             False       other   0.00    0.0    0.0    0.0
# 4             False       other   0.00    0.0    0.0    0.0
# ...             ...         ...    ...    ...    ...    ...
# 3178          False  structural   0.00    0.0    0.0    0.0
# 3179          False  structural   0.00    0.0    0.0    0.0
# 3180          False      debris   0.00    0.0    0.0    0.0
# 3181          False  structural   0.00    0.0    0.0    0.0
# 3182          False      debris   0.00    0.0    0.0    0.0
#
#       days_since_cleaned total_gal_binned  \
# 0                  164.0     (1000, 5000]
# 1                  164.0        (50, 250]
# 2                  164.0        (50, 250]
# 3                  164.0        (50, 250]
# 4                  164.0        (50, 250]
# ...                  ...              ...
# 3178               164.0     (1000, 5000]
# 3179               164.0      (250, 1000]
# 3180               164.0      (250, 1000]
# 3181               164.0         (15, 50]
# 3182               164.0      (250, 1000]
#
#                                   country_address  \
# 0     3200 THOUSAND OAKS DR,SAN ANTONIO,Texas,USA
# 1             6804 S FLORES,SAN ANTONIO,Texas,USA
# 2       215 Audrey Alene Dr,SAN ANTONIO,Texas,USA
# 3       3602 SE MILITARY DR,SAN ANTONIO,Texas,USA
# 4              100 PANSY LN,SAN ANTONIO,Texas,USA
# ...                                           ...
# 3178      NE LOOP 410 02383,SAN ANTONIO,Texas,USA
# 3179       ELDERBERRY 07407,SAN ANTONIO,Texas,USA
# 3180      BAYWATER DR 07019,SAN ANTONIO,Texas,USA
# 3181       JOHN BARRY 125/1,SAN ANTONIO,Texas,USA
# 3182                                          NaN
#
#                                                location    zip_code   age  \
# 0     3200, Thousand Oaks Drive, Horseshoe Bend, Los...       78746  22.0
# 1     Flores, West Odessa, Ector County, Texas, Unit...       Texas  31.0
# 2     215, Audrey Alene Drive, San Antonio, Bexar Co...       78216  64.0
# 3     Quality Suites, Southeast Military Drive, Hill...       78223  36.0
# 4     Pansy Lane, San Antonio, Bexar County, Texas, ...       78209  67.0
# ...                                                 ...         ...   ...
# 3178  Northeast Loop 410, San Antonio, Bexar County,...  78220-1930  43.0
# 3179  Elderberry, Camp Willow, Guadalupe County, Tex...       Texas  33.0
# 3180  Baywater Drive, San Antonio, Bexar County, Tex...       78229  51.0
# 3181                                                NaN        None  37.0
# 3182  Nanno, Comunità della Val di Non, Provincia di...       38012  52.0
#
#      age_binned  hours_spilled  precipitation  snowfall  snow_depth  avg_temp  \
# 0      (20, 25]       1.400000           0.00       0.0         0.0      69.0
# 1      (30, 35]       1.333333           0.00       0.0         0.0      69.0
# 2      (60, 65]       1.500000           0.03       0.0         0.0      74.0
# 3      (35, 40]       1.383333           0.03       0.0         0.0      74.0
# 4      (65, 70]       0.250000           0.00       0.0         0.0      42.0
# ...         ...            ...            ...       ...         ...       ...
# 3178   (40, 45]       1.000000           0.20       0.0         0.0      56.5
# 3179   (30, 35]       2.000000           0.00       0.0         0.0      41.5
# 3180   (50, 55]       0.750000           0.00       0.0         0.0      41.5
# 3181   (35, 40]       0.500000           0.00       0.0         0.0      41.5
# 3182   (50, 55]       2.000000           0.00       0.0         0.0      68.5
#
#       max_temp  min_temp  foggy  heavy_fog  thunder  hail  blowing_snow  rain  \
# 0           79        60      1          1        0     0             0     0
# 1           79        60      1          1        0     0             0     0
# 2           87        60      1          0        0     0             0     0
# 3           87        60      1          0        0     0             0     0
# 4           56        31      0          0        0     0             0     0
# ...        ...       ...    ...        ...      ...   ...           ...   ...
# 3178        70        43      1          0        0     1             0     1
# 3179        46        37      1          0        0     1             0     1
# 3180        46        37      1          0        0     1             0     1
# 3181        46        37      1          0        0     1             0     1
# 3182        83        54      1          1        0     0             1     0
#
#       precipitation_rolling_7  precipitation_rolling_14  \
# 0                4.285714e-03                  0.005714
# 1                4.285714e-03                  0.005714
# 2                4.285714e-03                  0.005714
# 3                4.285714e-03                  0.005714
# 4                2.857143e-03                  0.006429
# ...                       ...                       ...
# 3178             2.857143e-02                  0.015714
# 3179             2.478176e-18                  0.002143
# 3180             2.478176e-18                  0.002143
# 3181             2.478176e-18                  0.002143
# 3182             2.478176e-18                  0.002143
#
#       precipitation_rolling_30  avg_temp_rolling_7  avg_temp_rolling_14  \
# 0                     0.016333           54.285714            55.285714
# 1                     0.016333           54.285714            55.285714
# 2                     0.016333           51.714286            54.357143
# 3                     0.016333           51.714286            54.357143
# 4                     0.015667           46.571429            52.357143
# ...                        ...                 ...                  ...
# 3178                  0.015000           56.500000            58.107143
# 3179                  0.008333           56.214286            57.071429
# 3180                  0.008333           56.214286            57.071429
# 3181                  0.008333           56.214286            57.071429
# 3182                  0.008333           56.857143            56.500000
#
#       avg_temp_rolling_30  max_temp_rolling_7  max_temp_rolling_14  \
# 0               54.200000           65.857143            65.714286
# 1               54.200000           65.857143            65.714286
# 2               53.300000           62.142857            64.785714
# 3               53.300000           62.142857            64.785714
# 4               53.600000           55.142857            62.071429
# ...                   ...                 ...                  ...
# 3178            55.783333           67.000000            70.071429
# 3179            55.683333           67.714286            68.642857
# 3180            55.683333           67.714286            68.642857
# 3181            55.683333           67.714286            68.642857
# 3182            55.633333           70.857143            68.357143
#
#       max_temp_rolling_30  min_temp_rolling_7  min_temp_rolling_14  \
# 0               64.533333           46.000000            47.642857
# 1               64.533333           46.000000            47.642857
# 2               63.333333           42.571429            46.714286
# 3               63.333333           42.571429            46.714286
# 4               62.866667           38.571429            45.000000
# ...                   ...                 ...                  ...
# 3178            67.600000           46.000000            46.142857
# 3179            67.633333           44.714286            45.500000
# 3180            67.633333           44.714286            45.500000
# 3181            67.633333           44.714286            45.500000
# 3182            68.166667           42.857143            44.642857
#
#       min_temp_rolling_30
# 0               45.900000
# 1               45.900000
# 2               45.133333
# 3               45.133333
# 4               45.233333
# ...                   ...
# 3178            43.966667
# 3179            43.733333
# 3180            43.733333
# 3181            43.733333
# 3182            43.100000
#
# [3183 rows x 75 columns]

# %% [markdown]
# ### Train, Test Split
# ##### Final, we will split our data into:
# - train = 80%
# - test = 20%

# %%
train, test = train_test_split(df, train_size=.8, random_state=123)

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### Does the age of the sewer drive certain root causes?

# %% [markdown]
# Main Hypothesis:
# - $H_0$: The age of the sewer and the root cause are not related.
# - $H_a$: The age of the sewer and the root cause are related.

# %%
plt.rc('font',size=15)
explore.explore_age(train)
# Out:
# Hypothesis Testing:
# H_null: The age of the sewer is not correlated as the cause of the pipe damage involving a root_cause.
# H_alt: The age of the sewer is correlated as the cause of the pipe damage involving a root cause.
#
# Root Causes:
# 	structural, grease, debris, rain event, contractor, lift station, other, vandalism, roots, i/i, by pass pump leak,
#
# We reject the null hypothesis that the age of the sewer is correlated as the cause of the pipe damage invloving:
#
#  structural with an alpha of 0.01 and a p-value of 2.4121887282604853e-31:
#  grease with an alpha of 0.01 and a p-value of 1.091963355565286e-06:
#  debris with an alpha of 0.01 and a p-value of 1.7661473779460546e-06:
#  rain event with an alpha of 0.01 and a p-value of 0.00017993589988626508:
#  lift station with an alpha of 0.01 and a p-value of 1.118509797931134e-31:
#  vandalism with an alpha of 0.01 and a p-value of 0.005855989519204521:
# ----------------------------------------------------------------------------------------------------
# We fail to reject the null hypothesis that the age of the sewer is correlated as the cause of the pipe damage invloving:
#
#  contractor with an alpha of 0.01 and a p-value of 0.038640884023462635:
#  other with an alpha of 0.01 and a p-value of 0.05536296025013723:
#  roots with an alpha of 0.01 and a p-value of 0.06300688732477072:
#  i/i with an alpha of 0.01 and a p-value of 0.04679161021421001:

# %% [markdown]
# **Main Hypothesis:** restated
# - $H_0$: The age of the sewer and the root cause are not related.
# - $H_a$: The age of the sewer and the root cause are related.
#
# - since we reject the null hypothesis for the following root causes, we must reject the main null hypothesis:
#     - structural
#     - grease
#     - debris
#     - rain event
#     - lift station
#     - vandalism

# %% [markdown]
# ### Does the amount of rain drive certain root causes?

# %%
plt.rc('font',size=15)
explore.explore_rainfall(train)
# Out:
# Hypothesis Testing:
# H_null: The anount of rainfall is not correlated as the cause of the pipe damage involving a root_cause.
# H_alt: The anount of rainfall is correlated as the cause of the pipe damage involving a root cause.
#
# Root Causes:
# 	structural, grease, debris, rain event, contractor, lift station, other, vandalism, roots, i/i, by pass pump leak,
#
# We reject the null hypothesis that the amount of rainfall is correlated as the cause of the pipe damage invloving:
#
#  structural with an alpha of 0.01 and a p-value of 1.7102838954174988e-60:
#  grease with an alpha of 0.01 and a p-value of 6.041108950661502e-20:
#  debris with an alpha of 0.01 and a p-value of 4.532868889599897e-15:
#  rain event with an alpha of 0.01 and a p-value of 2.0801691583820262e-38:
#  contractor with an alpha of 0.01 and a p-value of 3.912296729165289e-06:
#  lift station with an alpha of 0.01 and a p-value of 0.006100756598997433:
#  other with an alpha of 0.01 and a p-value of 4.650654768977534e-21:
#  vandalism with an alpha of 0.01 and a p-value of 9.183115612009113e-13:
#  i/i with an alpha of 0.01 and a p-value of 0.007726667515162204:
# ----------------------------------------------------------------------------------------------------
# We fail to reject the null hypothesis that the amount of rainfall is correlated as the cause of the pipe damage invloving:
#
#  roots with an alpha of 0.01 and a p-value of 0.024386287905763037:

# %% [markdown]
# **Main Hypothesis:** restated
# - $H_0$: The amount of rainfall and the root cause are not related.
# - $H_a$: The amount of rainfall and the root cause are related.
#
# - since we reject the null hypothesis for the following root causes, we must reject the main null hypothesis:
#     - structural
#     - grease
#     - debris
#     - rain event
#     - lift station
#     - vandalism
#     - contractor
#     - i/i
#     - other

# %% [markdown]
# ### Does whether or not it rained drive certain root causes?

# %%
plt.rc('font',size=15)
explore.explore_rain(train)
# Out:
# Contingency Table
# rain                 0    1
# root_cause
# by pass pump leak    3    0
# contractor         133    6
# debris             295   70
# grease             419   70
# i/i                  1    7
# lift station        90   21
# other               46    4
# rain event         283   43
# roots               18    1
# structural         790  197
# vandalism           44    5
# *****************************************************************
# H_null: Rain is not correlated with the cause of the pipe damage.
# H_alt: Rain is correlated with the cause of the pipe damage.
#  with an alpha of 0.01 and a p-value of 3.529488721663625e-10:
#
# We reject the null hypothesis.
# Rain is correlated with the cause of the pipe damage
# Hypothesis Testing:
# H_null: Rain is not correlated as the cause of the pipe damage involving a root_cause.
# H_alt: Rain is correlated as the cause of the pipe damage involving a root cause.
#
# Root Causes:
# 	structural, grease, debris, rain event, contractor, lift station, other, vandalism, roots, i/i, by pass pump leak,
#
# We reject the null hypothesis that rain is correlated as the cause of the pipe damage invloving:
#
#  structural with an alpha of 0.01 and a p-value of 2.7445718289973744e-215:
#  grease with an alpha of 0.01 and a p-value of 1.3740302046065684e-106:
#  debris with an alpha of 0.01 and a p-value of 5.747169003132438e-80:
#  rain event with an alpha of 0.01 and a p-value of 5.540496890241234e-71:
#  contractor with an alpha of 0.01 and a p-value of 5.1456865189752425e-27:
#  lift station with an alpha of 0.01 and a p-value of 1.5122709995154007e-24:
#  other with an alpha of 0.01 and a p-value of 9.942851193120108e-10:
#  vandalism with an alpha of 0.01 and a p-value of 4.957166651565904e-10:
# ----------------------------------------------------------------------------------------------------
# We fail to reject the null hypothesis that rain is correlated as the cause of the pipe damage invloving:
#
#  roots with an alpha of 0.01 and a p-value of 0.03955473041656698:
#  i/i with an alpha of 0.01 and a p-value of 0.22544231699450948:

# %% [markdown]
# **Main Hypothesis:** restated
# - $H_0$: Rain and the root cause are not related.
# - $H_a$: Rain and the root cause are related.
#
# - since we reject the null hypothesis for the following root causes, we must reject the main null hypothesis:
#     - structural
#     - grease
#     - debris
#     - rain event
#     - lift station
#     - vandalism
#     - contractor
#     - i/i
#     - other

# %% [markdown]
# ### Does the temperature drive certain root causes?

# %% [markdown]
# #### Maximum Temperature

# %%
explore.explore_max_temp(train)
# Out:
# Hypothesis Testing:
# H_null: Max tempurature is not correlated as the cause of the pipe damage involving a root_cause.
# H_alt: Max tempurature is correlated as the cause of the pipe damage involving a root cause.
#
# Root Causes:
# 	structural, grease, debris, rain event, contractor, lift station, other, vandalism, roots, i/i, by pass pump leak,
#
# We reject the null hypothesis that max tempurature is correlated as the cause of the pipe damage invloving:
#
#  lift station with an alpha of 0.01 and a p-value of 0.004931454391636043:
# ----------------------------------------------------------------------------------------------------
# We fail to reject the null hypothesis that max tempurature is correlated as the cause of the pipe damage invloving:
#
#  structural with an alpha of 0.01 and a p-value of 0.0437846982890007:
#  grease with an alpha of 0.01 and a p-value of 0.1564421159023603:
#  debris with an alpha of 0.01 and a p-value of 0.12488765473905385:
#  rain event with an alpha of 0.01 and a p-value of 0.013746006480003296:
#  contractor with an alpha of 0.01 and a p-value of 0.3390867810003352:
#  other with an alpha of 0.01 and a p-value of 0.9688592044279085:
#  vandalism with an alpha of 0.01 and a p-value of 0.8501675657479353:
#  roots with an alpha of 0.01 and a p-value of 0.09292799491868056:
#  i/i with an alpha of 0.01 and a p-value of 0.08117467052224472:

# %% [markdown]
# **Main Hypothesis:** restated
# - $H_0$: The high temperature of the day a SSO event occurred and the root cause are not related.
# - $H_a$: The high temperature of the day a SSO event occurred and the root cause are related.
#
# - since we reject the null hypothesis for the following root cause, we must to reject the main null hypothesis:
#     - lift station

# %% [markdown]
# #### Minimum Temperature

# %%
explore.explore_min_temp(train)
# Out:
# Hypothesis Testing:
# H_null: Minimum temperature is not correlated as the cause of the pipe damage involving a root_cause.
# H_alt: Minimum temperature is correlated as the cause of the pipe damage involving a root cause.
#
# Root Causes:
# 	structural, grease, debris, rain event, contractor, lift station, other, vandalism, roots, i/i, by pass pump leak,
#
# We reject the null hypothesis that minimum temperature is correlated as the cause of the pipe damage invloving:
#
#  structural with an alpha of 0.01 and a p-value of 1.6974837821355497e-230:
#  grease with an alpha of 0.01 and a p-value of 2.9636447577713094e-124:
#  debris with an alpha of 0.01 and a p-value of 4.077871154900634e-102:
#  rain event with an alpha of 0.01 and a p-value of 1.2688094408034376e-101:
#  contractor with an alpha of 0.01 and a p-value of 1.7015445685265714e-38:
#  lift station with an alpha of 0.01 and a p-value of 2.6401898559369945e-38:
#  other with an alpha of 0.01 and a p-value of 1.327484174125047e-13:
#  vandalism with an alpha of 0.01 and a p-value of 3.288464982057179e-17:
#  roots with an alpha of 0.01 and a p-value of 2.386335193216198e-09:
# ----------------------------------------------------------------------------------------------------
# We fail to reject the null hypothesis that minimum temperature is correlated as the cause of the pipe damage invloving:
#
#  i/i with an alpha of 0.01 and a p-value of 0.10730802260139868:

# %% [markdown]
# **Main Hypothesis:** restated
# - $H_0$: The low temperature of the day a SSO event occurred and the root cause are not related.
# - $H_a$: The low temperature of the day a SSO event occurred and the root cause are not related.
#
# - since we reject the null hypothesis for the following root causes, we must reject the main null hypothesis:
#     - structural
#     - rain event

# %% [markdown]
# #### Average Temperature

# %%
explore.explore_avg_temp(train)
# Out:
# Hypothesis Testing:
# H_null: The average temperature is not correlated as the cause of the pipe damage involving a root_cause.
# H_alt: The average temperature is correlated as the cause of the pipe damage involving a root cause.
#
# Root Causes:
# 	structural, grease, debris, rain event, contractor, lift station, other, vandalism, roots, i/i, by pass pump leak,
#
# We reject the null hypothesis that the average temperature is correlated as the cause of the pipe damage invloving:
#
#  structural with an alpha of 0.01 and a p-value of 0.0032301723907314592:
#  rain event with an alpha of 0.01 and a p-value of 0.0005279598786638425:
#  lift station with an alpha of 0.01 and a p-value of 0.004562725756672607:
# ----------------------------------------------------------------------------------------------------
# We fail to reject the null hypothesis that the average temperature is correlated as the cause of the pipe damage invloving:
#
#  grease with an alpha of 0.01 and a p-value of 0.46314099699948796:
#  debris with an alpha of 0.01 and a p-value of 0.5803604762877066:
#  contractor with an alpha of 0.01 and a p-value of 0.850626149210665:
#  other with an alpha of 0.01 and a p-value of 0.7241682045006974:
#  vandalism with an alpha of 0.01 and a p-value of 0.25485765342400235:
#  roots with an alpha of 0.01 and a p-value of 0.1094290087823294:
#  i/i with an alpha of 0.01 and a p-value of 0.4110300682075373:

# %% [markdown]
# **Main Hypothesis:** restated
# - $H_0$: The average temperature of the day a SSO event occurred and the root cause are not related.
# - $H_a$: The average temperature of the day a SSO event occurred and the root cause are not related.
#
# - since we reject the null hypothesis for the following root causes, we must reject the main null hypothesis:
#     - structural
#     - rain event
#     - lift station

# %% [markdown]
# ## Modeling
#
# ### Prepocessing
#
# * What are we changing?
#     * We are removing several columns that we believe will not help the model
#         * 'sso_id', 'report_date', 'spill_address_num', 'spill_st_name', 'spill_stop', 'spill_start', 'cause', 'comments', 'actions', 'month', 'year', 'week', 'spill_address_full', 'last_cleaned', 'response_dttm', 'prevspill_24mos', 'public_notice', 'country_address', 'location', 'inches_no', 'rainfall_last3', 'unit_id', 'unit_id2', 'zip_code', 'discharge_to', 'discharge_route', 'council_district', 'time_spilled', 'hrs', 'gals_ret', 'pipe_diam', 'pipe_len', 'response_time', 'days_since_cleaned', 'age'
#     * We are one hot encoding the categorical columns
#         * "watershed", "earz_zone", "pipe_type", "inst_year", "unit_type", "asset_type", "age_binned", "total_gal_binned"

# %%
df = preprocessing.get_model_data()

# %% [markdown]
# ### Decision Tree Model
#
# #### Let's split the data

# %%
X = df.drop(columns='root_cause')
y = df.root_cause

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=13)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .25, random_state=13)

# %% [markdown]
# #### Now let's make the model. Through testing we found the the best parameters for our model to be the following:

# %%
tree = DecisionTreeClassifier(max_depth=6, min_samples_leaf=5, criterion='entropy', random_state=13)
tree.fit(X_train, y_train)

print(f'Accuracy Score on Train: {tree.score(X_train, y_train) * 100:.2f}%')
print(f'Accuracy Score on Val: {tree.score(X_val, y_val) * 100:.2f}%')
# Out:
# Accuracy Score on Train: 57.78%
# Accuracy Score on Val: 55.89%

# %% [markdown]
# #### We can see that our model doesn't appear to be overfit.
# #### Let's look at the classification report for the validation set.

# %%
preds = tree.predict(X_val)
print(classification_report(y_val, preds))
# Out:
#                    precision    recall  f1-score   support
#
# by pass pump leak       0.00      0.00      0.00         1
#        contractor       0.40      0.06      0.10        36
#            debris       0.00      0.00      0.00        83
#            grease       0.36      0.55      0.44       122
#               i/i       0.00      0.00      0.00         5
#      lift station       0.80      0.75      0.77        32
#             other       0.00      0.00      0.00        16
#        rain event       0.75      0.84      0.79        81
#             roots       0.00      0.00      0.00         5
#        structural       0.61      0.79      0.69       246
#         vandalism       0.00      0.00      0.00        10
#
#          accuracy                           0.56       637
#         macro avg       0.27      0.27      0.25       637
#      weighted avg       0.46      0.56      0.49       637

# %% [markdown]
# This report shows us we are getting:
#
# - 68% on 246 structural
# - 76% on 81 rain event
# - 81% on 32 lift station
# - 42% on 122 grease

# %%
print(f'These percentages equate to ' +\
f'{pd.Series([.68,.76,.81,.42]).mean()*100}% accuracy on ' +\
f'{round((246+81+32+122)/637*100,2)}% of the data')
# Out:
# These percentages equate to 66.75% accuracy on 75.51% of the data

# %% [markdown]
# #### The code below allows for us to look at how the tree is making decision.

# %%
# dot_data = export_graphviz(tree, 
#                            feature_names= X_train.columns.tolist(),
#                            class_names= y_train.value_counts(normalize=True).index.sort_values().tolist(),
#                            out_file=None) 
# graph = graphviz.Source(dot_data) 

# graph.render('saws-prediction-tree', view=True)

# %% [markdown]
# #### Since this was the best model we made let's see how it ran on the test data

# %%
tree.score(X_test, y_test)
# Out:
# 0.5196232339089482

# %%
preds = tree.predict(X_test)
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#   contractor       0.12      0.02      0.04        41
#       debris       0.00      0.00      0.00        96
#       grease       0.34      0.53      0.41       123
#          i/i       0.00      0.00      0.00         3
# lift station       0.71      0.85      0.77        26
#        other       0.00      0.00      0.00        13
#   rain event       0.67      0.76      0.71        75
#        roots       0.00      0.00      0.00         4
#   structural       0.58      0.77      0.66       243
#    vandalism       0.00      0.00      0.00        13
#
#     accuracy                           0.52       637
#    macro avg       0.24      0.29      0.26       637
# weighted avg       0.40      0.52      0.45       637
